# %%
import pandas

# %%
# !pwd
# Out:
# /Users/stone20091652/GitHub/OMOOCData/Doing math in python

# %%
data = pandas.read_csv('examples/brain_size.csv')

# %%
data
# Out:
#    ;"Gender";"FSIQ";"VIQ";"PIQ";"Weight";"Height";"MRI_Count"
# 0          1;"Female";133;132;124;"118";"64.5";816932
# 1             2;"Male";140;150;124;".";"72.5";1001121
# 2           3;"Male";139;123;150;"143";"73.3";1038437
# 3            4;"Male";133;129;128;"172";"68.8";965353
# 4          5;"Female";137;132;134;"147";"65.0";951545
# 5            6;"Female";99;90;110;"146";"69.0";928799
# 6          7;"Female";138;136;131;"138";"64.5";991305
# 7             8;"Female";92;90;98;"175";"66.0";854258
# 8               9;"Male";89;93;84;"134";"66.3";904858
# 9           10;"Male";133;114;147;"172";"68.8";955466
# 10        11;"Female";132;129;124;"118";"64.5";833868
# 11         12;"Male";141;150;128;"151";"70.0";1079549
# 12          13;"Male";135;129;124;"155";"69.0";924059
# 13        14;"Female";140;120;147;"155";"70.5";856472
# 14          15;"Female";96;100;90;"146";"66.0";878897
# 15           16;"Female";83;71;96;"135";"68.0";865363
# 16        17;"Female";132;132;120;"127";"68.5";852244
# 17           18;"Male";100;96;102;"178";"73.5";945088
# 18         19;"Female";101;112;84;"136";"66.3";808020
# 19             20;"Male";80;77;86;"180";"70.0";889083
# 20                  21;"Male";83;83;86;".";".";892420
# 21            22;"Male";97;107;84;"186";"76.5";905940
# 22        23;"Female";135;129;134;"122";"62.0";790619
# 23          24;"Male";139;145;128;"132";"68.0";955003
# 24          25;"Female";91;86;102;"114";"63.0";831772
# 25          26;"Male";141;145;131;"171";"72.0";935494
# 26           27;"Female";85;90;84;"140";"68.0";798612
# 27          28;"Male";103;96;110;"187";"77.0";1062462
# 28           29;"Female";77;83;72;"106";"63.0";793549
# 29        30;"Female";130;126;124;"159";"66.5";866662
# 30        31;"Female";133;126;132;"127";"62.5";857782
# 31          32;"Male";144;145;137;"191";"67.0";949589
# 32           33;"Male";103;96;110;"192";"75.5";997925
# 33             34;"Male";90;96;86;"181";"69.0";879987
# 34           35;"Female";83;90;81;"143";"66.5";834344
# 35        36;"Female";133;129;128;"153";"66.5";948066
# 36          37;"Male";140;150;124;"144";"70.5";949395
# 37           38;"Female";88;86;94;"139";"64.5";893983
# 38             39;"Male";81;90;74;"148";"74.0";930016
# 39             40;"Male";89;91;89;"179";"75.5";935863

# %%
data.head()
# Out:
#   ;"Gender";"FSIQ";"VIQ";"PIQ";"Weight";"Height";"MRI_Count"
# 0         1;"Female";133;132;124;"118";"64.5";816932
# 1            2;"Male";140;150;124;".";"72.5";1001121
# 2          3;"Male";139;123;150;"143";"73.3";1038437
# 3           4;"Male";133;129;128;"172";"68.8";965353
# 4         5;"Female";137;132;134;"147";"65.0";951545

# %%
data = pandas.read_csv('examples/brain_size.csv', sep = ';', na_values = '.')  ##补全没有显示的值

# %%
data
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0            1  Female   133  132  124     118    64.5     816932
# 1            2    Male   140  150  124     NaN    72.5    1001121
# 2            3    Male   139  123  150     143    73.3    1038437
# 3            4    Male   133  129  128     172    68.8     965353
# 4            5  Female   137  132  134     147    65.0     951545
# 5            6  Female    99   90  110     146    69.0     928799
# 6            7  Female   138  136  131     138    64.5     991305
# 7            8  Female    92   90   98     175    66.0     854258
# 8            9    Male    89   93   84     134    66.3     904858
# 9           10    Male   133  114  147     172    68.8     955466
# 10          11  Female   132  129  124     118    64.5     833868
# 11          12    Male   141  150  128     151    70.0    1079549
# 12          13    Male   135  129  124     155    69.0     924059
# 13          14  Female   140  120  147     155    70.5     856472
# 14          15  Female    96  100   90     146    66.0     878897
# 15          16  Female    83   71   96     135    68.0     865363
# 16          17  Female   132  132  120     127    68.5     852244
# 17          18    Male   100   96  102     178    73.5     945088
# 18          19  Female   101  112   84     136    66.3     808020
# 19          20    Male    80   77   86     180    70.0     889083
# 20          21    Male    83   83   86     NaN     NaN     892420
# 21          22    Male    97  107   84     186    76.5     905940
# 22          23  Female   135  129  134     122    62.0     790619
# 23          24    Male   139  145  128     132    68.0     955003
# 24          25  Female    91   86  102     114    63.0     831772
# 25          26    Male   141  145  131     171    72.0     935494
# 26          27  Female    85   90   84     140    68.0     798612
# 27          28    Male   103   96  110     187    77.0    1062462
# 28          29  Female    77   83   72     106    63.0     793549
# 29          30  Female   130  126  124     159    66.5     866662
# 30          31  Female   133  126  132     127    62.5     857782
# 31          32    Male   144  145  137     191    67.0     949589
# 32          33    Male   103   96  110     192    75.5     997925
# 33          34    Male    90   96   86     181    69.0     879987
# 34          35  Female    83   90   81     143    66.5     834344
# 35          36  Female   133  129  128     153    66.5     948066
# 36          37    Male   140  150  124     144    70.5     949395
# 37          38  Female    88   86   94     139    64.5     893983
# 38          39    Male    81   90   74     148    74.0     930016
# 39          40    Male    89   91   89     179    75.5     935863

# %%
import numpy as no
import numpy as np

# %%
t = np.linspace(-6, 6, 20)

# %%
np.linspace?

# %%
sin_t = np.sin(t)

# %%
cos_t = np.cos(t)

# %%
pandas.DataFrame({'t' : t, 'sin' : sin_t, 'cos' : cos_t})
# Out:
#          cos       sin         t
# 0   0.960170  0.279415 -6.000000
# 1   0.609977  0.792419 -5.368421
# 2   0.024451  0.999701 -4.736842
# 3  -0.570509  0.821291 -4.105263
# 4  -0.945363  0.326021 -3.473684
# 5  -0.955488 -0.295030 -2.842105
# 6  -0.596979 -0.802257 -2.210526
# 7  -0.008151 -0.999967 -1.578947
# 8   0.583822 -0.811882 -0.947368
# 9   0.950551 -0.310567 -0.315789
# 10  0.950551  0.310567  0.315789
# 11  0.583822  0.811882  0.947368
# 12 -0.008151  0.999967  1.578947
# 13 -0.596979  0.802257  2.210526
# 14 -0.955488  0.295030  2.842105
# 15 -0.945363 -0.326021  3.473684
# 16 -0.570509 -0.821291  4.105263
# 17  0.024451 -0.999701  4.736842
# 18  0.609977 -0.792419  5.368421
# 19  0.960170 -0.279415  6.000000

# %%
data.shape
# Out:
# (40, 8)

# %%
data.columns
# Out:
# Index([u'Unnamed: 0', u'Gender', u'FSIQ', u'VIQ', u'PIQ', u'Weight', u'Height',
#        u'MRI_Count'],
#       dtype='object')

# %%
data['Gender']
# Out:
# 0     Female
# 1       Male
# 2       Male
# 3       Male
# 4     Female
# 5     Female
# 6     Female
# 7     Female
# 8       Male
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13    Female
# 14    Female
# 15    Female
# 16    Female
# 17      Male
# 18    Female
# 19      Male
# 20      Male
# 21      Male
# 22    Female
# 23      Male
# 24    Female
# 25      Male
# 26    Female
# 27      Male
# 28    Female
# 29    Female
# 30    Female
# 31      Male
# 32      Male
# 33      Male
# 34    Female
# 35    Female
# 36      Male
# 37    Female
# 38      Male
# 39      Male
# Name: Gender, dtype: object

# %%
data[data['Gender'] == 'Female'] #只看Female的数据
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0            1  Female   133  132  124     118    64.5     816932
# 4            5  Female   137  132  134     147    65.0     951545
# 5            6  Female    99   90  110     146    69.0     928799
# 6            7  Female   138  136  131     138    64.5     991305
# 7            8  Female    92   90   98     175    66.0     854258
# 10          11  Female   132  129  124     118    64.5     833868
# 13          14  Female   140  120  147     155    70.5     856472
# 14          15  Female    96  100   90     146    66.0     878897
# 15          16  Female    83   71   96     135    68.0     865363
# 16          17  Female   132  132  120     127    68.5     852244
# 18          19  Female   101  112   84     136    66.3     808020
# 22          23  Female   135  129  134     122    62.0     790619
# 24          25  Female    91   86  102     114    63.0     831772
# 26          27  Female    85   90   84     140    68.0     798612
# 28          29  Female    77   83   72     106    63.0     793549
# 29          30  Female   130  126  124     159    66.5     866662
# 30          31  Female   133  126  132     127    62.5     857782
# 34          35  Female    83   90   81     143    66.5     834344
# 35          36  Female   133  129  128     153    66.5     948066
# 37          38  Female    88   86   94     139    64.5     893983

# %%
data[data['Gender'] == 'Female']['VIQ']#Female 中 VIQ
# Out:
# 0     132
# 4     132
# 5      90
# 6     136
# 7      90
# 10    129
# 13    120
# 14    100
# 15     71
# 16    132
# 18    112
# 22    129
# 24     86
# 26     90
# 28     83
# 29    126
# 30    126
# 34     90
# 35    129
# 37     86
# Name: VIQ, dtype: int64

# %%
data[data['Gender'] == 'Female']['VIQ'].mean()#VIQ的平均数
# Out:
# 109.45

# %%
data.describe() #
# Out:
#        Unnamed: 0        FSIQ         VIQ        PIQ      Weight     Height  \
# count   40.000000   40.000000   40.000000   40.00000   38.000000  39.000000
# mean    20.500000  113.450000  112.350000  111.02500  151.052632  68.525641
# std     11.690452   24.082071   23.616107   22.47105   23.478509   3.994649
# min      1.000000   77.000000   71.000000   72.00000  106.000000  62.000000
# 25%     10.750000   89.750000   90.000000   88.25000  135.250000  66.000000
# 50%     20.500000  116.500000  113.000000  115.00000  146.500000  68.000000
# 75%     30.250000  135.500000  129.750000  128.00000  172.000000  70.500000
# max     40.000000  144.000000  150.000000  150.00000  192.000000  77.000000
#
#             MRI_Count
# count       40.000000
# mean    908755.000000
# std      72282.048931
# min     790619.000000
# 25%     855918.500000
# 50%     905399.000000
# 75%     950078.000000
# max    1079549.000000

# %%
groupby_gender = data.groupby('Gender')

# %%
for gender, value in groupby_gender: #groupby can quick look the dataset
    print gender, value.mean()
# Out:
# Female Unnamed: 0        19.650
# FSIQ             111.900
# VIQ              109.450
# PIQ              110.450
# Weight           137.200
# Height            65.765
# MRI_Count     862654.600
# dtype: float64
# Male Unnamed: 0        21.350000
# FSIQ             115.000000
# VIQ              115.250000
# PIQ              111.600000
# Weight           166.444444
# Height            71.431579
# MRI_Count     954855.400000
# dtype: float64

# %%
groupby_gender.mean()
# Out:
#         Unnamed: 0   FSIQ     VIQ     PIQ      Weight     Height  MRI_Count
# Gender
# Female       19.65  111.9  109.45  110.45  137.200000  65.765000   862654.6
# Male         21.35  115.0  115.25  111.60  166.444444  71.431579   954855.4

# %% [markdown]
# + What is the mean value for VIQ for the full population?
# + How many males/females were included in this study?
# Hint use ‘tab completion’ to find out the methods that can be called, instead of ‘mean’ in the above example.
# + What is the average value of MRI counts expressed in log units, for males and females?

# %%
data['VIQ'].mean()
# Out:
# 112.35

# %%
groupby_gender.count()
# Out:
#         Unnamed: 0  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# Gender
# Female          20    20   20   20      20      20         20
# Male            20    20   20   20      18      19         20

# %%
for gender, value in groupby_gender['MRI_Count']:
    print gender, np.log(value).mean()
# Out:
# Female 13.6658295129
# Male 13.767731055

# %%
np.log(groupby_gender['MRI_Count'].mean())
# Out:
# Gender
# Female    13.667769
# Male      13.769315
# Name: MRI_Count, dtype: float64

# %%
np.log?

# %%
data['log_MRI'] = np.log(data.MRI_Count)

# %%
groupby_gender = data.groupby('Gender')

# %%
groupby_gender.MRI_Count.mean()
# Out:
# Gender
# Female    862654
# Male      954855
# Name: MRI_Count, dtype: int64

# %%
groupby_gender.log_MRI.mean()
# Out:
# Gender
# Female    13.665830
# Male      13.767731
# Name: log_MRI, dtype: float64

# %%
from pandas.tools import plotting
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plotting.scatter_matrix(data[['Weight', 'Height', 'MRI_Count']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11282aa50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1118bde10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11184ba10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x111b55490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11156b550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1115a7250>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1118fb210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111a4b0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111e08310>]], dtype=object)

# %%
plotting.scatter_matrix?

# %%
plt.title('Females')

# %% [markdown]
# # Hypothesis testing: comparing two groups

# %%
from scipy import stats

# %%
stats.ttest_1samp(data['VIQ'], 0)
# Out:
# Ttest_1sampResult(statistic=30.088099970849328, pvalue=1.3289196468728067e-28)

# %%
stats.ttest_1samp?

# %%
female_VIQ = data[data['Gender'] == 'Female']['VIQ']

# %%
male_VIQ = data[data['Gender'] == 'Male']['VIQ']

# %%
stats.ttest_ind(female_VIQ, male_VIQ)
# Out:
# Ttest_indResult(statistic=-0.77261617232750113, pvalue=0.44452876778583217)

# %%
stats.ttest_1samp(data.FSIQ - data.PIQ, 0)
# Out:
# Ttest_1sampResult(statistic=1.7842019405859857, pvalue=0.082172638183642358)

# %%
stats.ttest_ind(data[data.Gender == 'Female'].Weight, data[data.Gender == 'Male'].Weight)
# Out:
# Ttest_indResult(statistic=nan, pvalue=nan)

# %%
data.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
data_no_nans = data.dropna()

# %%
data_no_nans.shape
# Out:
# (38, 9)

# %%
data.shape
# Out:
# (40, 9)

# %% [markdown]
# 去掉了两个没有weight的值

# %%
stats.ttest_ind(data_no_nans[data_no_nans.Gender == 'Female'].Weight, data_no_nans[data_no_nans.Gender == 'Male'].Weight)
# Out:
# Ttest_indResult(statistic=-4.8709509219406959, pvalue=2.2272930183621181e-05)

# %% [markdown]
# # linear models

# %% [markdown]
# ## linear regression

# %%
x = np.linspace(-5, 5, 20)

# %%
y = -5 + 3*x + 4*np.random.normal(size = x.shape)

# %%
data = pandas.DataFrame({"x" : x, "y" : y})

# %%
data
# Out:
#            x          y
# 0  -5.000000 -12.951616
# 1  -4.473684 -16.536586
# 2  -3.947368 -14.430993
# 3  -3.421053 -17.575527
# 4  -2.894737 -16.964518
# 5  -2.368421  -8.592819
# 6  -1.842105 -11.082083
# 7  -1.315789 -15.818611
# 8  -0.789474  -9.099643
# 9  -0.263158 -10.637180
# 10  0.263158  -7.878456
# 11  0.789474   2.453850
# 12  1.315789   2.694024
# 13  1.842105  -3.504911
# 14  2.368421  -1.503509
# 15  2.894737  -4.628716
# 16  3.421053   5.947751
# 17  3.947368   4.495954
# 18  4.473684   4.835387
# 19  5.000000  14.048771

# %%
from statsmodels.formula.api import ols

# %%
model = ols('y ~ x + 1', data).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.805
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     74.42
# Date:                Sun, 28 Feb 2016   Prob (F-statistic):           8.23e-08
# Time:                        07:12:38   Log-Likelihood:                -55.810
# No. Observations:                  20   AIC:                             115.6
# Df Residuals:                      18   BIC:                             117.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -5.8365      0.929     -6.282      0.000        -7.788    -3.885
# x              2.6408      0.306      8.627      0.000         1.998     3.284
# ==============================================================================
# Omnibus:                        1.252   Durbin-Watson:                   1.613
# Prob(Omnibus):                  0.535   Jarque-Bera (JB):                0.904
# Skew:                           0.198   Prob(JB):                        0.636
# Kurtosis:                       2.037   Cond. No.                         3.03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model.params
# Out:
# Intercept   -5.836472
# x            2.640797
# dtype: float64

# %%
model.*?

# %%
# Out:
#            x          y
# 0  -5.000000 -12.951616
# 1  -4.473684 -16.536586
# 2  -3.947368 -14.430993
# 3  -3.421053 -17.575527
# 4  -2.894737 -16.964518
# 5  -2.368421  -8.592819
# 6  -1.842105 -11.082083
# 7  -1.315789 -15.818611
# 8  -0.789474  -9.099643
# 9  -0.263158 -10.637180
# 10  0.263158  -7.878456
# 11  0.789474   2.453850
# 12  1.315789   2.694024
# 13  1.842105  -3.504911
# 14  2.368421  -1.503509
# 15  2.894737  -4.628716
# 16  3.421053   5.947751
# 17  3.947368   4.495954
# 18  4.473684   4.835387
# 19  5.000000  14.048771

# %%
data = pandas.read_csv('examples/brain_size.csv', sep = ';', na_values = '.')  ##补全没有显示的值

# %%
data
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0            1  Female   133  132  124     118    64.5     816932
# 1            2    Male   140  150  124     NaN    72.5    1001121
# 2            3    Male   139  123  150     143    73.3    1038437
# 3            4    Male   133  129  128     172    68.8     965353
# 4            5  Female   137  132  134     147    65.0     951545
# 5            6  Female    99   90  110     146    69.0     928799
# 6            7  Female   138  136  131     138    64.5     991305
# 7            8  Female    92   90   98     175    66.0     854258
# 8            9    Male    89   93   84     134    66.3     904858
# 9           10    Male   133  114  147     172    68.8     955466
# 10          11  Female   132  129  124     118    64.5     833868
# 11          12    Male   141  150  128     151    70.0    1079549
# 12          13    Male   135  129  124     155    69.0     924059
# 13          14  Female   140  120  147     155    70.5     856472
# 14          15  Female    96  100   90     146    66.0     878897
# 15          16  Female    83   71   96     135    68.0     865363
# 16          17  Female   132  132  120     127    68.5     852244
# 17          18    Male   100   96  102     178    73.5     945088
# 18          19  Female   101  112   84     136    66.3     808020
# 19          20    Male    80   77   86     180    70.0     889083
# 20          21    Male    83   83   86     NaN     NaN     892420
# 21          22    Male    97  107   84     186    76.5     905940
# 22          23  Female   135  129  134     122    62.0     790619
# 23          24    Male   139  145  128     132    68.0     955003
# 24          25  Female    91   86  102     114    63.0     831772
# 25          26    Male   141  145  131     171    72.0     935494
# 26          27  Female    85   90   84     140    68.0     798612
# 27          28    Male   103   96  110     187    77.0    1062462
# 28          29  Female    77   83   72     106    63.0     793549
# 29          30  Female   130  126  124     159    66.5     866662
# 30          31  Female   133  126  132     127    62.5     857782
# 31          32    Male   144  145  137     191    67.0     949589
# 32          33    Male   103   96  110     192    75.5     997925
# 33          34    Male    90   96   86     181    69.0     879987
# 34          35  Female    83   90   81     143    66.5     834344
# 35          36  Female   133  129  128     153    66.5     948066
# 36          37    Male   140  150  124     144    70.5     949395
# 37          38  Female    88   86   94     139    64.5     893983
# 38          39    Male    81   90   74     148    74.0     930016
# 39          40    Male    89   91   89     179    75.5     935863

# %%
data.Gender
# Out:
# 0     Female
# 1       Male
# 2       Male
# 3       Male
# 4     Female
# 5     Female
# 6     Female
# 7     Female
# 8       Male
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13    Female
# 14    Female
# 15    Female
# 16    Female
# 17      Male
# 18    Female
# 19      Male
# 20      Male
# 21      Male
# 22    Female
# 23      Male
# 24    Female
# 25      Male
# 26    Female
# 27      Male
# 28    Female
# 29    Female
# 30    Female
# 31      Male
# 32      Male
# 33      Male
# 34    Female
# 35    Female
# 36      Male
# 37    Female
# 38      Male
# 39      Male
# Name: Gender, dtype: object

# %%
model = ols('VIQ ~ Gender + 1', data).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    VIQ   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.5969
# Date:                Sun, 28 Feb 2016   Prob (F-statistic):              0.445
# Time:                        07:34:37   Log-Likelihood:                -182.42
# No. Observations:                  40   AIC:                             368.8
# Df Residuals:                      38   BIC:                             372.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# Intercept        109.4500      5.308     20.619      0.000        98.704   120.196
# Gender[T.Male]     5.8000      7.507      0.773      0.445        -9.397    20.997
# ==============================================================================
# Omnibus:                       26.188   Durbin-Watson:                   1.709
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                3.703
# Skew:                           0.010   Prob(JB):                        0.157
# Kurtosis:                       1.510   Cond. No.                         2.62
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
data.head()
# Out:
#    Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0           1  Female   133  132  124     118    64.5     816932
# 1           2    Male   140  150  124     NaN    72.5    1001121
# 2           3    Male   139  123  150     143    73.3    1038437
# 3           4    Male   133  129  128     172    68.8     965353
# 4           5  Female   137  132  134     147    65.0     951545

# %% [markdown]
# ## Multiple Regression

# %%
data = pandas.read_csv('examples/iris.csv')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width       name
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# 18            5.7          3.8           1.7          0.3     setosa
# 19            5.1          3.8           1.5          0.3     setosa
# 20            5.4          3.4           1.7          0.2     setosa
# 21            5.1          3.7           1.5          0.4     setosa
# 22            4.6          3.6           1.0          0.2     setosa
# 23            5.1          3.3           1.7          0.5     setosa
# 24            4.8          3.4           1.9          0.2     setosa
# 25            5.0          3.0           1.6          0.2     setosa
# 26            5.0          3.4           1.6          0.4     setosa
# 27            5.2          3.5           1.5          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 133           6.3          2.8           5.1          1.5  virginica
# 134           6.1          2.6           5.6          1.4  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas
# %matplotlib inline

# %%
# For 3d plots. This import is necessary to have 3D plotting below
from mpl_toolkits.mplot3d import Axes3D
# For statistics. Requires statsmodels 5.0 or more
from statsmodels.formula.api import ols
# Analysis of Variance (ANOVA) on linear models
from statsmodels.stats.anova import anova_lm

# %%
# Generate and show the data
x = np.linspace(-5, 5, 21)
# We generate a 2D grid
X, Y = np.meshgrid(x, x)

# To get reproducable values, provide a seed value
np.random.seed(1)

# Z is the elevation of this 2D grid
Z = -5 + 3*X - 0.5*Y + 8 * np.random.normal(size=X.shape)

# Plot the data
fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap=plt.cm.coolwarm,
                       rstride=1, cstride=1)
ax.view_init(20, -120)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

##############################################################################
# Multilinear regression model, calculating fit, P-values, confidence
# intervals etc.

# Convert the data into a Pandas DataFrame to use the formulas framework
# in statsmodels

# First we need to flatten the data: it's 2D layout is not relevent.
X = X.flatten()
Y = Y.flatten()
Z = Z.flatten()

data = pandas.DataFrame({'x': X, 'y': Y, 'z': Z})

# Fit the model
model = ols("z ~ x + y", data).fit()

# Print the summary
print(model.summary())

print("\nRetrieving manually the parameter estimates:")
print(model._results.params)
# should be array([-4.99754526,  3.00250049, -0.50514907])

# Peform analysis of variance on fitted linear model
anova_results = anova_lm(model)

print('\nANOVA results')
print(anova_results)

plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      z   R-squared:                       0.594
# Model:                            OLS   Adj. R-squared:                  0.592
# Method:                 Least Squares   F-statistic:                     320.4
# Date:                Sun, 28 Feb 2016   Prob (F-statistic):           1.89e-86
# Time:                        09:43:13   Log-Likelihood:                -1537.7
# No. Observations:                 441   AIC:                             3081.
# Df Residuals:                     438   BIC:                             3094.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -4.5052      0.378    -11.924      0.000        -5.248    -3.763
# x              3.1173      0.125     24.979      0.000         2.872     3.363
# y             -0.5109      0.125     -4.094      0.000        -0.756    -0.266
# ==============================================================================
# Omnibus:                        0.260   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.878   Jarque-Bera (JB):                0.204
# Skew:                          -0.052   Prob(JB):                        0.903
# Kurtosis:                       3.015   Cond. No.                         3.03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Retrieving manually the parameter estimates:
# [-4.50523303  3.11734237 -0.51091248]
#
# ANOVA results
#            df        sum_sq       mean_sq           F        PR(>F)
# x           1  39284.301219  39284.301219  623.962799  2.888238e-86
# y           1   1055.220089   1055.220089   16.760336  5.050899e-05
# Residual  438  27576.201607     62.959364         NaN           NaN

# %% [markdown]
# # seaborn

# %%
import urllib
import os

import matplotlib.pyplot as plt
# %matplotlib inline
##############################################################################
# Load the data
import pandas

# %%
# Give names to the columns
names = [
    'EDUCATION: Number of years of education',
    'SOUTH: 1=Person lives in South, 0=Person lives elsewhere',
    'SEX: 1=Female, 0=Male',
    'EXPERIENCE: Number of years of work experience',
    'UNION: 1=Union member, 0=Not union member',
    'WAGE: Wage (dollars per hour)',
    'AGE: years',
    'RACE: 1=Other, 2=Hispanic, 3=White',
    'OCCUPATION: 1=Management, 2=Sales, 3=Clerical, 4=Service, 5=Professional, 6=Other',
    'SECTOR: 0=Other, 1=Manufacturing, 2=Construction',
    'MARR: 0=Unmarried,  1=Married',
]

# %%
short_names = [n.split(':')[0] for n in names]

data = pandas.read_csv('wages.txt', skiprows=27, skipfooter=6, sep=None,
                       header=None)
data.columns = short_names

# Log-transform the wages, because they typically are increased with
# multiplicative factors
import numpy as np
data['WAGE'] = np.log10(data['WAGE'])

##############################################################################
# Plot scatter matrices highlighting different aspects

import seaborn
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg')

seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg', hue='SEX')
plt.suptitle('Effect of gender: 1=Female, 0=Male')

seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg', hue='RACE')
plt.suptitle('Effect of race: 1=Other, 2=Hispanic, 3=White')

seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg', hue='UNION')
plt.suptitle('Effect of union: 1=Union member, 0=Not union member')


##############################################################################
# Plot a simple regression

seaborn.lmplot(y='WAGE', x='EDUCATION', data=data)

plt.show()
# Out:
# /Users/stone20091652/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
# /Users/stone20091652/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# /Users/stone20091652/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
